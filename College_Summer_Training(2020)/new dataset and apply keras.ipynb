# %%
import numpy as np
import pandas as pd

# %%
dataset= pd.read_csv('datasets_672162_1182853_dataset.csv')
dataset.head(20)
# Out:
#              Disease             Symptom_1              Symptom_2  \
# 0   Fungal infection               itching              skin_rash
# 1   Fungal infection             skin_rash   nodal_skin_eruptions
# 2   Fungal infection               itching   nodal_skin_eruptions
# 3   Fungal infection               itching              skin_rash
# 4   Fungal infection               itching              skin_rash
# 5   Fungal infection             skin_rash   nodal_skin_eruptions
# 6   Fungal infection               itching   nodal_skin_eruptions
# 7   Fungal infection               itching              skin_rash
# 8   Fungal infection               itching              skin_rash
# 9   Fungal infection               itching              skin_rash
# 10           Allergy   continuous_sneezing              shivering
# 11           Allergy             shivering                 chills
# 12           Allergy   continuous_sneezing                 chills
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
list_drop=['Symptom_4','Symptom_5','Symptom_6','Symptom_7','Symptom_8','Symptom_9','Symptom_10','Symptom_11','Symptom_12','Symptom_13','Symptom_14','Symptom_15','Symptom_16','Symptom_17',]

# %%
dataset.drop(list_drop,axis=1, inplace= True)

# %%
dataset.head(10)
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 5  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 6  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 7  Fungal infection     itching              skin_rash    dischromic _patches
# 8  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 9  Fungal infection     itching              skin_rash   nodal_skin_eruptions

# %%
pd.unique(dataset.Disease)
# Out:
# array(['Fungal infection', 'Allergy', 'GERD', 'Chronic cholestasis',
#        'Drug Reaction', 'Peptic ulcer diseae', 'AIDS', 'Diabetes ',
#        'Gastroenteritis', 'Bronchial Asthma', 'Hypertension ', 'Migraine',
#        'Cervical spondylosis', 'Paralysis (brain hemorrhage)', 'Jaundice',
#        'Malaria', 'Chicken pox', 'Dengue', 'Typhoid', 'hepatitis A',
#        'Hepatitis B', 'Hepatitis C', 'Hepatitis D', 'Hepatitis E',
#        'Alcoholic hepatitis', 'Tuberculosis', 'Common Cold', 'Pneumonia',
#        'Dimorphic hemmorhoids(piles)', 'Heart attack', 'Varicose veins',
#        'Hypothyroidism', 'Hyperthyroidism', 'Hypoglycemia',
#        'Osteoarthristis', 'Arthritis',
#        '(vertigo) Paroymsal  Positional Vertigo', 'Acne',
#        'Urinary tract infection', 'Psoriasis', 'Impetigo'], dtype=object)

# %%
sym= pd.read_csv('datasets_672162_1182853_symptom_Description.csv')

# %%
print(sym)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
dataset= dataset.drop_duplicates(subset='Disease')

# %%
dataset.shape
# Out:
# (41, 4)

# %%
dataset
# Out:
#                                      Disease             Symptom_1  \
# 0                           Fungal infection               itching
# 10                                   Allergy   continuous_sneezing
# 20                                      GERD          stomach_pain
# 30                       Chronic cholestasis               itching
# 40                             Drug Reaction               itching
# 50                       Peptic ulcer diseae              vomiting
# 60                                      AIDS        muscle_wasting
# 70                                 Diabetes                fatigue
# 80                           Gastroenteritis              vomiting
# 90                          Bronchial Asthma               fatigue
# 100                            Hypertension               headache
# 110                                 Migraine               acidity
# 120                     Cervical spondylosis             back_pain
# ...

# %%
precaution= pd.read_csv('datasets_672162_1182853_symptom_precaution.csv')

# %%
precaution
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
sd_diff= dataset.merge(sym, left_on='Disease',right_on ='Disease')

# %%
sd_diff.head()
# Out:
#                Disease             Symptom_1   Symptom_2  \
# 0     Fungal infection               itching   skin_rash
# 1              Allergy   continuous_sneezing   shivering
# 2                 GERD          stomach_pain     acidity
# 3  Chronic cholestasis               itching    vomiting
# 4        Drug Reaction               itching   skin_rash
#
#                Symptom_3                                        Description
# 0   nodal_skin_eruptions  In humans, fungal infections occur when an inv...
# 1                 chills  An allergy is an immune system response to a f...
# 2       ulcers_on_tongue  Gastroesophageal reflux disease, or GERD, is a...
# 3         yellowish_skin  Chronic cholestatic diseases, whether occurrin...
# 4           stomach_pain  An adverse drug reaction (ADR) is an injury ca...

# %%
sd_diff=sd_diff.merge(precaution, left_on='Disease',right_on='Disease')

# %%
sd_diff.head()
# Out:
#                Disease             Symptom_1   Symptom_2  \
# 0     Fungal infection               itching   skin_rash
# 1              Allergy   continuous_sneezing   shivering
# 2                 GERD          stomach_pain     acidity
# 3  Chronic cholestasis               itching    vomiting
# 4        Drug Reaction               itching   skin_rash
#
#                Symptom_3                                        Description  \
# 0   nodal_skin_eruptions  In humans, fungal infections occur when an inv...
# 1                 chills  An allergy is an immune system response to a f...
# 2       ulcers_on_tongue  Gastroesophageal reflux disease, or GERD, is a...
# 3         yellowish_skin  Chronic cholestatic diseases, whether occurrin...
# 4           stomach_pain  An adverse drug reaction (ADR) is an injury ca...
#
#              Precaution_1                        Precaution_2  \
# 0              bath twice  use detol or neem in bathing water
# ...

# %%
sd_diff
# Out:
#                                     Disease             Symptom_1  \
# 0                          Fungal infection               itching
# 1                                   Allergy   continuous_sneezing
# 2                                      GERD          stomach_pain
# 3                       Chronic cholestasis               itching
# 4                             Drug Reaction               itching
# 5                       Peptic ulcer diseae              vomiting
# 6                                      AIDS        muscle_wasting
# 7                           Gastroenteritis              vomiting
# 8                          Bronchial Asthma               fatigue
# 9                                  Migraine               acidity
# 10                     Cervical spondylosis             back_pain
# 11             Paralysis (brain hemorrhage)              vomiting
# 12                                 Jaundice               itching
# ...

# %%
import sklearn

# %% [markdown]
# ## Base model

# %% [markdown]
# #### convert catagorical data to numerical data in diff

# %%
from sklearn.model_selection import train_test_split

# %%
diff=sd_diff
diff.head()
# Out:
#                Disease             Symptom_1   Symptom_2  \
# 0     Fungal infection               itching   skin_rash
# 1              Allergy   continuous_sneezing   shivering
# 2                 GERD          stomach_pain     acidity
# 3  Chronic cholestasis               itching    vomiting
# 4        Drug Reaction               itching   skin_rash
#
#                Symptom_3                                        Description  \
# 0   nodal_skin_eruptions  In humans, fungal infections occur when an inv...
# 1                 chills  An allergy is an immune system response to a f...
# 2       ulcers_on_tongue  Gastroesophageal reflux disease, or GERD, is a...
# 3         yellowish_skin  Chronic cholestatic diseases, whether occurrin...
# 4           stomach_pain  An adverse drug reaction (ADR) is an injury ca...
#
#              Precaution_1                        Precaution_2  \
# 0              bath twice  use detol or neem in bathing water
# ...

# %%
diff['disease']= pd.factorize(diff.Disease)[0]

# %%
diff.head()
# Out:
#                Disease             Symptom_1   Symptom_2  \
# 0     Fungal infection               itching   skin_rash
# 1              Allergy   continuous_sneezing   shivering
# 2                 GERD          stomach_pain     acidity
# 3  Chronic cholestasis               itching    vomiting
# 4        Drug Reaction               itching   skin_rash
#
#                Symptom_3                                        Description  \
# 0   nodal_skin_eruptions  In humans, fungal infections occur when an inv...
# 1                 chills  An allergy is an immune system response to a f...
# 2       ulcers_on_tongue  Gastroesophageal reflux disease, or GERD, is a...
# 3         yellowish_skin  Chronic cholestatic diseases, whether occurrin...
# 4           stomach_pain  An adverse drug reaction (ADR) is an injury ca...
#
#              Precaution_1                        Precaution_2  \
# 0              bath twice  use detol or neem in bathing water
# ...

# %%
'''
mySddf=diff
mySddf.to_csv('mySddf.csv')'''

# %%
diff=pd.read_csv('symptomID.csv')

diff.head()
# Out:
#    disease              Disease  Symptom_1  Symptom_2  Symptom_3  \
# 0        0     Fungal infection       0.58       0.45       0.40
# 1        1              Allergy       0.22       0.43       0.20
# 2        2                 GERD       0.47       0.11       0.51
# 3        3  Chronic cholestasis       0.58       0.52       0.57
# 4        4        Drug Reaction       0.58       0.45       0.47
#
#                                          Description            Precaution_1  \
# 0  In humans, fungal infections occur when an inv...              bath twice
# 1  An allergy is an immune system response to a f...          apply calamine
# 2  Gastroesophageal reflux disease, or GERD, is a...  avoid fatty spicy food
# 3  Chronic cholestatic diseases, whether occurrin...              cold baths
# 4  An adverse drug reaction (ADR) is an injury ca...         stop irritation
#
#                          Precaution_2             Precaution_3  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
did=diff.groupby('disease')
x=did['Symptom_1'].agg(np.mean)
y=did['Symptom_2'].agg(np.mean)
z=did['Symptom_3'].agg(np.mean)\


x,y,z
# Out:
# (disease
#  0     0.58
#  1     0.22
#  2     0.47
#  3     0.58
#  4     0.58
#  5     0.52
#  6     0.36
#  7     0.52
#  8     0.26
#  9     0.11
#  10    0.13
#  11    0.52
#  12    0.58
#  13    0.20
#  14    0.58
#  15    0.45
#  16    0.20
#  17    0.31
#  18    0.58
#  19    0.26
#  20    0.31
#  21    0.31
#  22    0.52
#  23    0.20
#  24    0.22
#  25    0.20
#  26    0.52
#  27    0.26
#  28    0.26
#  29    0.26
#  30    0.52
#  31    0.31
#  32    0.37
#  33    0.52
#  34    0.45
#  35    0.19
#  36    0.45
#  37    0.45
#  Name: Symptom_1, dtype: float64,
#  disease
#  0     0.45
#  1     0.43
#  2     0.11
#  3     0.52
#  4     0.45
#  5     0.34
#  6     0.41
#  7     0.48
#  8     0.23
#  9     0.30
#  10    0.53
#  11    0.28
#  12    0.52
#  13    0.52
#  14    0.45
#  15    0.20
#  16    0.52
#  17    0.52
#  18    0.26
#  19    0.57
#  20    0.52
#  21    0.52
#  22    0.57
#  23    0.52
#  24    0.20
#  25    0.26
#  26    0.17
#  27    0.24
#  28    0.55
# ...

# %%
plt.figure(figsize=(16,5))
plt.plot(z, 'go')
plt.xlabel('disease ID')
plt.ylabel('symptom ID')
# Out:
# Text(0, 0.5, 'symptom ID')

# %%
dataset=diff

# %%
dataset= dataset.drop_duplicates(subset='Disease')

# %%
dataset = dataset.drop(columns=['Disease','Description','Precaution_1','Precaution_2','Precaution_3','Precaution_4'])

# %%
dataset.head(10)dataset.describe()
# Out:
#    disease  Symptom_1  Symptom_2  Symptom_3
# 0        0       0.58       0.45       0.40
# 1        1       0.22       0.43       0.20
# 2        2       0.47       0.11       0.51
# 3        3       0.58       0.52       0.57
# 4        4       0.58       0.45       0.47
# 5        5       0.52       0.34       0.10
# 6        6       0.36       0.41       0.29
# 7        7       0.52       0.48       0.25
# 8        8       0.26       0.23       0.29
# 9        9       0.11       0.30       0.28

# %%
dataset.describe()
# Out:
#          disease  Symptom_1  Symptom_2  Symptom_3
# count  38.000000  38.000000  38.000000  38.000000
# mean   18.500000   0.377105   0.382895   0.318158
# std    11.113055   0.151478   0.135385   0.134543
# min     0.000000   0.110000   0.110000   0.100000
# 25%     9.250000   0.260000   0.265000   0.252500
# 50%    18.500000   0.365000   0.415000   0.285000
# 75%    27.750000   0.520000   0.520000   0.397500
# max    37.000000   0.580000   0.570000   0.570000

# %%
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import keras


from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
''''
dataframe = diff
dataset = dataframe.values
Y = dataframe.Disease            #column[:,0:4].astype(int)
X = dataset[:,2:5].astype(float)

#dataset
#dataframe
X,Y'''
# Out:
# "'\ndataframe = diff\ndataset = dataframe.values\nY = dataframe.Disease            #column[:,0:4].astype(int)\nX = dataset[:,2:5].astype(float)\n\n#dataset\n#dataframe\nX,Y"

# %%
X = dataset.drop(columns='disease')
X.head()
# Out:
#    Symptom_1  Symptom_2  Symptom_3
# 0       0.58       0.45       0.40
# 1       0.22       0.43       0.20
# 2       0.47       0.11       0.51
# 3       0.58       0.52       0.57
# 4       0.58       0.45       0.47

# %%
Y = dataset[['disease']]

# %%
# encode class values as integers
#encoder = LabelEncoder()
#encoder.fit(Y)
#encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
#dummy_y = np_utils.to_categorical(encoded_Y)
#dummy_y

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
#Y_test[1:2]

# %%
Y_test.head()
# Out:
#     disease
# 34       34
# 30       30
# 29       29
# 0         0
# 28       28

# %%
# define baseline model
def baseline_model():
# create model
    model = Sequential()
    model.add(Dense(100, input_dim=3, activation='relu'))
   # model.add(Dropout(0.5))
    model.add(Dense(37, activation = "softmax"))
# Compile model
        
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
seed = 7
np.random.seed(seed)

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=5, batch_size=15, verbose=0)

# %%
kfold = KFold(n_splits=10, shuffle=True)
results = cross_val_score(estimator, X_train, Y_train, cv=kfold)

print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Baseline: 3.33% (10.00%)

# %%
results
# Out:
# array([0.33333334, 0.        , 0.        , 0.        , 0.33333334,
#        0.33333334, 0.        , 0.        , 0.        , 0.33333334])

# %%
model = baseline_model()


# Batch size should be in the multiple of 2 e.g 64, 128, 256 etc
model.fit(X_train,Y_train,validation_split=0.1, epochs=150,batch_size=64)
# Out:
# Train on 27 samples, validate on 3 samples
# Epoch 1/150
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-153-19845f951a5c> in <module>
#       3
#       4 # Batch size should be in the multiple of 2 e.g 64, 128, 256 etc
# ----> 5 model.fit(X_train,Y_train,validation_split=0.1, epochs=150,batch_size=64)
#
# ~\.conda\envs\tf-gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# ...
